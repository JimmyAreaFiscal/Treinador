# %%
from modules.graphs.graph_builders import training_workflow_builder

workout_graph = training_workflow_builder()
workout_graph

# %%
workout_graph.compile()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Documents/Projetos/Vida Pessoal/Treinador/myvenv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Documents/Projetos/Vida Pessoal/Treinador/myvenv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File /usr/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
# ...
